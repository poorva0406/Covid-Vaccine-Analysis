# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('~/Desktop/SEM 6 Assign/DATA SCI/covid_vaccine_statewise.csv')
df.head(10)
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
# 5  21/01/2021  India                  365965.0   32226.0  12600.0
# 6  22/01/2021  India                  549381.0   36988.0  14115.0
# 7  23/01/2021  India                  759008.0   43076.0  15605.0
# 8  24/01/2021  India                  835058.0   49851.0  18111.0
# 9  25/01/2021  India                 1277104.0   55151.0  19682.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# ...

# %%
df.tail(10)
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 7835  06/08/2021  West Bengal                31774086.0  930084.0   2485.0
# 7836  07/08/2021  West Bengal                32029325.0  727057.0   1833.0
# 7837  08/08/2021  West Bengal                32098768.0  271684.0    584.0
# 7838  09/08/2021  West Bengal                32390378.0  866173.0   2086.0
# 7839  10/08/2021  West Bengal                       NaN       NaN      NaN
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# 7835               22745949.0                 9028137.0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
# ...

# %%
statewise = df.groupby('State')
statewise.first()
# Out:
#                                           Updated On  \
# State
# Andaman and Nicobar Islands               16/01/2021
# Andhra Pradesh                            16/01/2021
# Arunachal Pradesh                         16/01/2021
# Assam                                     16/01/2021
# Bihar                                     16/01/2021
# Chandigarh                                16/01/2021
# Chhattisgarh                              16/01/2021
# Dadra and Nagar Haveli and Daman and Diu  16/01/2021
# Delhi                                     16/01/2021
# Goa                                       16/01/2021
# Gujarat                                   16/01/2021
# Haryana                                   16/01/2021
# Himachal Pradesh                          16/01/2021
# India                                     16/01/2021
# Jammu and Kashmir                         16/01/2021
# Jharkhand                                 16/01/2021
# ...

# %%
df1 = statewise['First Dose Administered']
df1.first()
# Out:
# State
# Andaman and Nicobar Islands                    23.0
# Andhra Pradesh                               4216.0
# Arunachal Pradesh                              81.0
# Assam                                         401.0
# Bihar                                        2967.0
# Chandigarh                                    120.0
# Chhattisgarh                                 1040.0
# Dadra and Nagar Haveli and Daman and Diu       23.0
# Delhi                                         892.0
# Goa                                            50.0
# Gujarat                                      1146.0
# Haryana                                      1864.0
# Himachal Pradesh                              202.0
# India                                       48276.0
# Jammu and Kashmir                             377.0
# Jharkhand                                     344.0
# Karnataka                                    3810.0
# Kerala                                       1681.0
# ...

# %%
df2 = statewise['Second Dose Administered']
df2.first()
# Out:
# State
# Andaman and Nicobar Islands                 0.0
# Andhra Pradesh                              0.0
# Arunachal Pradesh                           0.0
# Assam                                       0.0
# Bihar                                       0.0
# Chandigarh                                  0.0
# Chhattisgarh                                0.0
# Dadra and Nagar Haveli and Daman and Diu    0.0
# Delhi                                       0.0
# Goa                                         0.0
# Gujarat                                     0.0
# Haryana                                     0.0
# Himachal Pradesh                            0.0
# India                                       0.0
# Jammu and Kashmir                           0.0
# Jharkhand                                   0.0
# Karnataka                                   0.0
# Kerala                                      0.0
# Ladakh                                      0.0
# ...

# %%
print('The total number of females vaccinated for covid-19 : ', df['Female(Individuals Vaccinated)'].sum())
# Out:
# The total number of females vaccinated for covid-19 :  6321628736.0

# %%
print('The total number of males vaccinated for covid-19 : ', df['Male(Individuals Vaccinated)'].sum())
# Out:
# The total number of males vaccinated for covid-19 :  7138698858.0
